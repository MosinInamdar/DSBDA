# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# prompt: make groups of categorical data species from the data set such that i can find the mean for sepal_length of each group

iris.groupby("species")["sepal_length"].mean()
# Out:
# species
# setosa        5.006
# versicolor    5.936
# virginica     6.588
# Name: sepal_length, dtype: float64

# %%
iris.groupby("species")["sepal_length"].median()
# Out:
# species
# setosa        5.0
# versicolor    5.9
# virginica     6.5
# Name: sepal_length, dtype: float64

# %%
iris.groupby("species")["sepal_length"].std()
# Out:
# species
# setosa        0.352490
# versicolor    0.516171
# virginica     0.635880
# Name: sepal_length, dtype: float64

# %%
iris.groupby("species")["sepal_length"].max()
# Out:
# species
# setosa        5.8
# versicolor    7.0
# virginica     7.9
# Name: sepal_length, dtype: float64

# %%
iris.groupby("species")["sepal_length"].min()
# Out:
# species
# setosa        4.3
# versicolor    4.9
# virginica     4.9
# Name: sepal_length, dtype: float64

# %%
planets = sns.load_dataset("planets")
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
planets.describe()
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000

# %%
planets.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
mean_orbital_period = planets['orbital_period'].astype('float').mean()
mean_orbital_period
# Out:
# 2002.9175960947582

# %%
planets['orbital_period'].replace(np.NaN, mean_orbital_period, inplace = True)
planets['orbital_period']
# Out:
# 0       269.300000
# 1       874.774000
# 2       763.000000
# 3       326.030000
# 4       516.220000
#            ...
# 1030      3.941507
# 1031      2.615864
# 1032      3.191524
# 1033      4.125083
# 1034      4.187757
# Name: orbital_period, Length: 1035, dtype: float64

# %%
mean_mass = planets['mass'].astype('float').mean()
mean_mass
planets['mass'].replace(np.NaN, mean_mass, inplace = True)
planets['mass']
# Out:
# 0        7.100000
# 1        2.210000
# 2        2.600000
# 3       19.400000
# 4       10.500000
#           ...
# 1030     2.638161
# 1031     2.638161
# 1032     2.638161
# 1033     2.638161
# 1034     2.638161
# Name: mass, Length: 1035, dtype: float64

# %%
mean_distance = planets['distance'].astype('float').mean()
mean_distance
planets['distance'].replace(np.NaN, mean_distance, inplace = True)
planets['distance']
# Out:
# 0        77.40
# 1        56.95
# 2        19.84
# 3       110.62
# 4       119.47
#          ...
# 1030    172.00
# 1031    148.00
# 1032    174.00
# 1033    293.00
# 1034    260.00
# Name: distance, Length: 1035, dtype: float64

# %%
planets.isnull().sum()
# Out:
# method            0
# number            0
# orbital_period    0
# mass              0
# distance          0
# year              0
# dtype: int64

# %%
planets.groupby("method")["mass"].mean()
# Out:
# method
# Astrometry                       2.638161
# Eclipse Timing Variations        3.190792
# Imaging                          2.638161
# Microlensing                     2.638161
# Orbital Brightness Modulation    2.638161
# Pulsar Timing                    2.638161
# Pulsation Timing Variations      2.638161
# Radial Velocity                  2.631279
# Transit                          2.635218
# Transit Timing Variations        2.638161
# Name: mass, dtype: float64

# %%
planets.groupby("method")["mass"].min()
# Out:
# method
# Astrometry                       2.638161
# Eclipse Timing Variations        2.638161
# Imaging                          2.638161
# Microlensing                     2.638161
# Orbital Brightness Modulation    2.638161
# Pulsar Timing                    2.638161
# Pulsation Timing Variations      2.638161
# Radial Velocity                  0.003600
# Transit                          1.470000
# Transit Timing Variations        2.638161
# Name: mass, dtype: float64

# %%
planets.groupby("method")["mass"].max()
# Out:
# method
# Astrometry                        2.638161
# Eclipse Timing Variations         6.050000
# Imaging                           2.638161
# Microlensing                      2.638161
# Orbital Brightness Modulation     2.638161
# Pulsar Timing                     2.638161
# Pulsation Timing Variations       2.638161
# Radial Velocity                  25.000000
# Transit                           2.638161
# Transit Timing Variations         2.638161
# Name: mass, dtype: float64

# %%
planets.groupby("method")["mass"].std()
# Out:
# method
# Astrometry                       0.000000
# Eclipse Timing Variations        1.190136
# Imaging                          0.000000
# Microlensing                     0.000000
# Orbital Brightness Modulation    0.000000
# Pulsar Timing                    0.000000
# Pulsation Timing Variations           NaN
# Radial Velocity                  3.673847
# Transit                          0.058628
# Transit Timing Variations        0.000000
# Name: mass, dtype: float64

# %%
planets.groupby("method")["mass"].median()
# Out:
# method
# Astrometry                       2.638161
# Eclipse Timing Variations        2.638161
# Imaging                          2.638161
# Microlensing                     2.638161
# Orbital Brightness Modulation    2.638161
# Pulsar Timing                    2.638161
# Pulsation Timing Variations      2.638161
# Radial Velocity                  1.500000
# Transit                          2.638161
# Transit Timing Variations        2.638161
# Name: mass, dtype: float64
